# %%
print("Hello, Data Analytics!")
# Out:
# Hello, Data Analytics!

# %%
import pandas as pd

# %%
orders = pd.read_csv("../data/raw/olist_orders_dataset.csv")

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders.shape
# Out:
# (99441, 8)

# %%
orders.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='object')

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
customers = pd.read_csv("../data/raw/olist_customers_dataset.csv")

products = pd.read_csv("../data/raw/olist_products_dataset.csv")

order_items = pd.read_csv("../data/raw/olist_order_items_dataset.csv")

payments = pd.read_csv("../data/raw/olist_order_payments_dataset.csv")

reviews = pd.read_csv("../data/raw/olist_order_reviews_dataset.csv")

sellers = pd.read_csv("../data/raw/olist_sellers_dataset.csv")

geolocation = pd.read_csv("../data/raw/olist_geolocation_dataset.csv")

category = pd.read_csv("../data/raw/product_category_name_translation.csv")

# %%
print("Orders:", orders.shape)
print("Customers:", customers.shape)
print("Products:", products.shape)
print("Order Items:", order_items.shape)
print("Payments:", payments.shape)
print("Reviews:", reviews.shape)
print("Sellers:", sellers.shape)
print("Geolocation:", geolocation.shape)
print("Category:", category.shape)
# Out:
# Orders: (99441, 8)
# Customers: (99441, 5)
# Products: (32951, 9)
# Order Items: (112650, 7)
# Payments: (103886, 5)
# Reviews: (99224, 7)
# Sellers: (3095, 4)
# Geolocation: (1000163, 5)
# Category: (71, 2)

# %%
print("Orders:", orders.shape)
print("Customers:", customers.shape)
print("Products:", products.shape)
print("Order Items:", order_items.shape)
print("Payments:", payments.shape)
print("Reviews:", reviews.shape)
print("Sellers:", sellers.shape)
print("Geolocation:", geolocation.shape)
print("Category:", category.shape)
# Out:
# Orders: (99441, 8)
# Customers: (99441, 5)
# Products: (32951, 9)
# Order Items: (112650, 7)
# Payments: (103886, 5)
# Reviews: (99224, 7)
# Sellers: (3095, 4)
# Geolocation: (1000163, 5)
# Category: (71, 2)

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
category.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders.dtypes
# Out:
# order_id                         object
# customer_id                      object
# order_status                     object
# order_purchase_timestamp         object
# order_approved_at                object
# order_delivered_carrier_date     object
# order_delivered_customer_date    object
# order_estimated_delivery_date    object
# dtype: object

# %%
orders["order_purchase_timestamp"] = pd.to_datetime(orders["order_purchase_timestamp"])

# %%
orders["order_approved_at"] = pd.to_datetime(orders["order_approved_at"])

orders["order_delivered_carrier_date"] = pd.to_datetime(orders["order_delivered_carrier_date"])

orders["order_delivered_customer_date"] = pd.to_datetime(orders["order_delivered_customer_date"])

orders["order_estimated_delivery_date"] = pd.to_datetime(orders["order_estimated_delivery_date"])

# %%
orders.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %%
orders["purchase_year"] = orders["order_purchase_timestamp"].dt.year

# %%
orders["purchase_month"] = orders["order_purchase_timestamp"].dt.month

# %%
orders["purchase_month_name"] = orders["order_purchase_timestamp"].dt.month_name()

# %%
orders["purchase_day"] = orders["order_purchase_timestamp"].dt.day

# %%
orders["purchase_day_name"] = orders["order_purchase_timestamp"].dt.day_name()

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders["purchase_year"].value_counts()
# Out:
# purchase_year
# 2018    54011
# 2017    45101
# 2016      329
# Name: count, dtype: int64

# %%
orders["purchase_month_name"].value_counts()
# Out:
# purchase_month_name
# August       10843
# May          10573
# July         10318
# March         9893
# June          9412
# April         9343
# February      8508
# January       8069
# November      7544
# December      5674
# October       4959
# September     4305
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
orders["purchase_month_name"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='purchase_month_name'>

# %%
plt.title("Orders by Month")
plt.xlabel("Month")
plt.ylabel("Number of Orders")
plt.show()

# %%
import matplotlib.pyplot as plt

month_orders = orders.groupby("purchase_month_name").size().reindex([
    "January","February","March","April","May","June",
    "July","August","September","October","November","December"
])

month_orders.plot(kind="bar", figsize=(10,5))

plt.title("Orders by Month")
plt.xlabel("Month")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)

plt.show()

# %%
orders["order_status"].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

orders["order_status"].value_counts().plot(
    kind="bar",
    figsize=(10,5)
)

plt.title("Orders by Status")
plt.xlabel("Order Status")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)

plt.show()

# %%
orders["delivery_days"] = (
    orders["order_delivered_customer_date"] -
    orders["order_purchase_timestamp"]
).dt.days

# %%
orders[["order_purchase_timestamp",
        "order_delivered_customer_date",
        "delivery_days"]].head()
# Out:
#   order_purchase_timestamp order_delivered_customer_date  delivery_days
# 0      2017-10-02 10:56:33           2017-10-10 21:25:13            8.0
# 1      2018-07-24 20:41:37           2018-08-07 15:27:45           13.0
# 2      2018-08-08 08:38:49           2018-08-17 18:06:29            9.0
# 3      2017-11-18 19:28:06           2017-12-02 00:28:42           13.0
# 4      2018-02-13 21:18:39           2018-02-16 18:17:02            2.0

# %%
orders["delivery_days"].mean()
# Out:
# np.float64(12.094085575687217)

# %%
round(orders["delivery_days"].mean(), 2)
# Out:
# np.float64(12.09)

# %%
orders_customers = orders.merge(
    customers,
    on="customer_id",
    how="left"
)

# %%
orders_customers.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders_customers["customer_state"].value_counts()
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

orders_customers["customer_state"] \
    .value_counts() \
    .head(10) \
    .plot(kind="bar", figsize=(10,5))

plt.title("Top 10 States by Orders")
plt.xlabel("State")
plt.ylabel("Number of Orders")

plt.show()

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_items["price"].sum()
# Out:
# np.float64(13591643.7)

# %%
round(order_items["price"].sum(), 2)
# Out:
# np.float64(13591643.7)

# %%
round(order_items["price"].mean(), 2)
# Out:
# np.float64(120.65)

# %%
order_items["price"].max()
# Out:
# np.float64(6735.0)

# %%
order_items["price"].min()
# Out:
# np.float64(0.85)

# %%
import matplotlib.pyplot as plt

order_items["price"].plot(
    kind="hist",
    bins=30,
    figsize=(10,5)
)

plt.title("Distribution of Product Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")

plt.show()

# %%
order_product = order_items.merge(
    products,
    on="product_id",
    how="left"
)

# %%
order_product.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1  2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %%
order_product = order_product.merge(
    category,
    on="product_category_name",
    how="left"
)

# %%
order_product.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1  2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %%
import matplotlib.pyplot as plt

category_sales.head(10).plot(
    kind="bar",
    figsize=(12,5)
)

plt.title("Top 10 Product Categories by Revenue")
plt.xlabel("Category")
plt.ylabel("Revenue")

plt.xticks(rotation=45)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 3
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 category_sales.head(10).plot(
#       4     kind="bar",
#       5     figsize=(12,5)
#       6 )
#
# NameError: name 'category_sales' is not defined

# %%
order_product.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1  2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %%
category_sales = order_product.groupby(
    "product_category_name_english"
)["price"].sum().sort_values(ascending=False)

category_sales.head(10)
# Out:
# product_category_name_english
# health_beauty            1258681.34
# watches_gifts            1205005.68
# bed_bath_table           1036988.68
# sports_leisure            988048.97
# computers_accessories     911954.32
# furniture_decor           729762.49
# cool_stuff                635290.85
# housewares                632248.66
# auto                      592720.11
# garden_tools              485256.46
# Name: price, dtype: float64

# %%
import matplotlib.pyplot as plt

category_sales.head(10).plot(
    kind="bar",
    figsize=(12,5)
)

plt.title("Top 10 Product Categories by Revenue")
plt.xlabel("Category")
plt.ylabel("Revenue")

plt.xticks(rotation=45)

plt.show()

# %%
orders.info()
customers.info()
products.info()
order_items.info()
payments.info()
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
#  8   purchase_year                  99441 non-null  int32
#  9   purchase_month                 99441 non-null  int32
#  10  purchase_month_name            99441 non-null  object
# ...

# %%
orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# purchase_year                       0
# purchase_month                      0
# purchase_month_name                 0
# purchase_day                        0
# purchase_day_name                   0
# delivery_days                    2965
# dtype: int64

# %%
orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# purchase_year                             int32
# purchase_month                            int32
# purchase_month_name                      object
# purchase_day                              int32
# purchase_day_name                        object
# delivery_days                           float64
# dtype: object

# %%
orders.to_csv(
    "../data/processed/orders_cleaned.csv",
    index=False
)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 orders.to_csv(
#       2     "../data/processed/orders_cleaned.csv",
#       3     index=False
#       4 )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Sai Dinesh\\OneDrive\\Desktop\\Retail-Sales-Analytics\\notebooks'

# %%
import os

os.listdir("../data")
# Out:
# ['processed', 'raw']

# %%
orders.to_csv("../data/processed/orders_cleaned.csv", index=False)

# %%
orders.to_csv("../data/processed/orders_cleaned.csv", index=False)

# %%
import os

os.access("../data/processed", os.W_OK)
# Out:
# True

# %%
with open("../data/processed/test.txt", "w") as f:
    f.write("Hello")

# %%
import pandas as pd

# %%
orders = pd.read_csv(
    "../data/raw/olist_orders_dataset.csv",
    parse_dates=[
        "order_purchase_timestamp",
        "order_approved_at",
        "order_delivered_carrier_date",
        "order_delivered_customer_date",
        "order_estimated_delivery_date"
    ]
)

# %%
orders.to_csv("../data/processed/orders_cleaned.csv", index=False)

# %%
import os

print(os.path.abspath("../data/processed"))
# Out:
# C:\Users\Sai Dinesh\OneDrive\Desktop\Retail-Sales-Analytics\data\processed

# %%
orders.to_csv(
    r"C:\Users\Sai Dinesh\OneDrive\Desktop\Retail-Sales-Analytics\data\processed\orders_cleaned.csv",
    index=False
)

# %%
year_orders = orders.groupby("purchase_year")["order_id"].count()

year_orders
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 year_orders = orders.groupby("purchase_year")["order_id"].count()
#       2
#       3 year_orders
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9206
#    9207         if level is None and by is None:
#    9208             raise TypeError("You have to supply one of 'by' and 'level'")
#    9209
# -> 9210         return DataFrameGroupBy(
#    9211             obj=self,
#    9212             keys=by,
#    9213             axis=axis,
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\groupby\groupby.py:1331, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
# ...

# %%
orders.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='object')

# %%
orders["purchase_year"] = orders["order_purchase_timestamp"].dt.year

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
year_orders = orders.groupby("purchase_year")["order_id"].count()

year_orders
# Out:
# purchase_year
# 2016      329
# 2017    45101
# 2018    54011
# Name: order_id, dtype: int64

# %%
orders["purchase_year"] = orders["order_purchase_timestamp"].dt.year
orders["purchase_month"] = orders["order_purchase_timestamp"].dt.month
orders["purchase_month_name"] = orders["order_purchase_timestamp"].dt.month_name()
orders["purchase_day"] = orders["order_purchase_timestamp"].dt.day
orders["purchase_day_name"] = orders["order_purchase_timestamp"].dt.day_name()

orders["delivery_days"] = (
    orders["order_delivered_customer_date"] -
    orders["order_purchase_timestamp"]
).dt.days

# %%
year_orders = orders.groupby("purchase_year")["order_id"].count()
year_orders
# Out:
# purchase_year
# 2016      329
# 2017    45101
# 2018    54011
# Name: order_id, dtype: int64

# %%
year_orders = orders.groupby("purchase_year")["order_id"].count()

year_orders
# Out:
# purchase_year
# 2016      329
# 2017    45101
# 2018    54011
# Name: order_id, dtype: int64

# %%
import matplotlib.pyplot as plt

year_orders.plot(
    kind="bar",
    figsize=(8,5)
)

plt.title("Orders by Year")
plt.xlabel("Year")
plt.ylabel("Number of Orders")
plt.xticks(rotation=0)

plt.show()

# %%
month_orders = orders.groupby("purchase_month_name")["order_id"].count()

month_orders
# Out:
# purchase_month_name
# April         9343
# August       10843
# December      5674
# February      8508
# January       8069
# July         10318
# June          9412
# March         9893
# May          10573
# November      7544
# October       4959
# September     4305
# Name: order_id, dtype: int64

# %%
orders.groupby("purchase_month_name")

# %%
["order_id"].count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 ["order_id"].count()
#
# TypeError: list.count() takes exactly one argument (0 given)

# %%
month_orders = orders.groupby("purchase_month_name")["order_id"].count()

month_orders
# Out:
# purchase_month_name
# April         9343
# August       10843
# December      5674
# February      8508
# January       8069
# July         10318
# June          9412
# March         9893
# May          10573
# November      7544
# October       4959
# September     4305
# Name: order_id, dtype: int64

# %%
month_order = [
    "January", "February", "March", "April",
    "May", "June", "July", "August",
    "September", "October", "November", "December"
]

month_orders = month_orders.reindex(month_order)

month_orders
# Out:
# purchase_month_name
# January       8069
# February      8508
# March         9893
# April         9343
# May          10573
# June          9412
# July         10318
# August       10843
# September     4305
# October       4959
# November      7544
# December      5674
# Name: order_id, dtype: int64

# %%
import matplotlib.pyplot as plt

month_orders.plot(
    kind="bar",
    figsize=(10,5)
)

plt.title("Orders by Month")
plt.xlabel("Month")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)

plt.show()

# %%
weekday_orders = orders.groupby("purchase_day_name")["order_id"].count()

weekday_orders
# Out:
# purchase_day_name
# Friday       14122
# Monday       16196
# Saturday     10887
# Sunday       11960
# Thursday     14761
# Tuesday      15963
# Wednesday    15552
# Name: order_id, dtype: int64

# %%
day_order = [
    "Monday",
    "Tuesday",
    "Wednesday",
    "Thursday",
    "Friday",
    "Saturday",
    "Sunday"
]

weekday_orders = weekday_orders.reindex(day_order)

weekday_orders
# Out:
# purchase_day_name
# Monday       16196
# Tuesday      15963
# Wednesday    15552
# Thursday     14761
# Friday       14122
# Saturday     10887
# Sunday       11960
# Name: order_id, dtype: int64

# %%
import matplotlib.pyplot as plt

weekday_orders.plot(
    kind="bar",
    figsize=(10,5)
)

plt.title("Orders by Weekday")
plt.xlabel("Weekday")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)

plt.show()

# %%
orders.groupby("purchase_day_name"["order_id"].count())
# Out:
# <>:1: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
# C:\Users\Sai Dinesh\AppData\Local\Temp\ipykernel_26264\601697541.py:1: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
#   orders.groupby("purchase_day_name"["order_id"].count())
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 orders.groupby("purchase_day_name"["order_id"].count())
#
# TypeError: string indices must be integers, not 'str'

# %%
orders["delivery_days"].mean()
# Out:
# np.float64(12.094085575687217)

# %%
orders["delivery_days"].min()
# Out:
# np.float64(0.0)

# %%
orders["delivery_days"].max()
# Out:
# np.float64(209.0)

# %%
orders["delivery_days"].describe()
# Out:
# count    96476.000000
# mean        12.094086
# std          9.551746
# min          0.000000
# 25%          6.000000
# 50%         10.000000
# 75%         15.000000
# max        209.000000
# Name: delivery_days, dtype: float64

# %%
import matplotlib.pyplot as plt

orders["delivery_days"].hist(
    bins=30,
    figsize=(10,5)
)

plt.title("Delivery Days Distribution")
plt.xlabel("Delivery Days")
plt.ylabel("Number of Orders")

plt.show()

# %%
orders["delivery_days"].mean()
# Out:
# np.float64(12.094085575687217)

# %%
orders["delivery_days"].min()
# Out:
# np.float64(0.0)

# %%
orders["delivery_days"].max()
# Out:
# np.float64(209.0)

# %%
orders["delivery_days"].min()
# Out:
# np.float64(0.0)

# %%
orders["delivery_days"].max()
# Out:
# np.float64(209.0)
